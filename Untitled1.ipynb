# %%
#Matplotlib era's tour

# %%
import matplotlib.pyplot as plt

# %%
#another import thing -- inorder to show visualizatin %matplotlib inline

# %%
# %matplotlib inline

# %%
# the basic examples we use 2 numpy arrays

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
y =x**2
x # inspace generated arr
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y # y version
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# create simple plot

# %%
plt.plot(x,y,'r') # the graph here
plt.xlabel('X Axis label') # added label here
plt.ylabel('Y Axis label') # added label here
plt.title('Title Goes Here')# add title text
# Out:
# Text(0.5, 1.0, 'Title Goes Here')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-');
